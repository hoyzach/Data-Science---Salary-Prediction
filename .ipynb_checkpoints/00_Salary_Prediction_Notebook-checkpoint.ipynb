# %% [markdown]
# # Salary Predictions Based on Job Descriptions

# %% [markdown]
# # Part 1 - DEFINE

# %% [markdown]
# ### ---- Define the problem ----

# %% [markdown]
# **Data has been gathered from job listings containing the ideal candidate's required qualifications, some aspects of the position & company, along with the posted salary. The purpose of this notebook is to predict salaries of job listings with similar information which neglected to post a salary. The final product will consolidate the pre-pocessing, feature engineering, training, and predicting into a pipeline for production. The end product may prove useful to recruiting firms and individual companies looking to remain competitive in the job market.**

# %%
# Author name and contact information
__author__ = "Zachary Hoy"
__email__ = "hoyzach@gmail.com"

# %%
# Import all relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing, metrics
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import inspect
import xgboost
import pickle
# %matplotlib inline

# %% [markdown]
# ## Part 2 - DISCOVER

# %% [markdown]
# ### ---- Load the data ----

# %%
# Load the data into a Pandas dataframe
raw_train_features = pd.read_csv("data/train_features.csv")
raw_train_targets = pd.read_csv("data/train_salaries.csv")
raw_test_features = pd.read_csv("data/test_features.csv")

# %% [markdown]
# ### ---- Clean the data ----

# %%
raw_train_features.shape
# Out:
# (1000000, 8)

# %%
raw_train_targets.shape
# Out:
# (1000000, 2)

# %%
# Get a general overview of the training features provided
raw_train_features.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis
# 0   HEALTH               10                   83
# 1      WEB                3                   73
# 2   HEALTH               10                   38
# 3     AUTO                8                   17
# 4  FINANCE                8                   16

# %%
# Get a general overview of the training targets provided
raw_train_targets.head()
# Out:
#               jobId  salary
# 0  JOB1362684407687     130
# 1  JOB1362684407688     101
# 2  JOB1362684407689     137
# 3  JOB1362684407690     142
# 4  JOB1362684407691     163

# %%
# Get a general overview of the testing features provided
raw_test_features.head()
# Out:
#               jobId companyId  jobType       degree    major industry  \
# 0  JOB1362685407687    COMP33  MANAGER  HIGH_SCHOOL     NONE   HEALTH
# 1  JOB1362685407688    COMP13   JUNIOR         NONE     NONE     AUTO
# 2  JOB1362685407689    COMP10      CTO      MASTERS  BIOLOGY   HEALTH
# 3  JOB1362685407690    COMP21  MANAGER  HIGH_SCHOOL     NONE      OIL
# 4  JOB1362685407691    COMP36   JUNIOR     DOCTORAL  BIOLOGY      OIL
#
#    yearsExperience  milesFromMetropolis
# 0               22                   73
# 1               20                   47
# 2               17                    9
# 3               14                   96
# 4               10                   44

# %%
# Check to see if both jobId columns of training features and targets are in the same order
compare_jobIds = np.where(raw_train_features["jobId"] == raw_train_targets["jobId"],True,False)
np.unique(compare_jobIds, return_counts=False)
# Out:
# array([ True])

# %%
raw_train_targets.duplicated().sum()
# Out:
# 0

# %%
# Check for duplicate rows
raw_train_features.duplicated().sum()
# Out:
# 0

# %%
# Merge feature and target train data into single dataframe and drop jobId as its a duplicate index
df = pd.merge(raw_train_features, raw_train_targets, on='jobId')
df = df.drop('jobId', axis=1)
df.head()
# Out:
#   companyId         jobType       degree      major industry  yearsExperience  \
# 0    COMP37             CFO      MASTERS       MATH   HEALTH               10
# 1    COMP19             CEO  HIGH_SCHOOL       NONE      WEB                3
# 2    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS   HEALTH               10
# 3    COMP38         MANAGER     DOCTORAL  CHEMISTRY     AUTO                8
# 4     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS  FINANCE                8
#
#    milesFromMetropolis  salary
# 0                   83     130
# 1                   73     101
# 2                   38     137
# 3                   17     142
# 4                   16     163

# %%
# Delete the original files to save memory
del raw_train_features
del raw_train_targets
del raw_test_features

# %%
# Check data types and null-values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   companyId            1000000 non-null  object
#  1   jobType              1000000 non-null  object
#  2   degree               1000000 non-null  object
#  3   major                1000000 non-null  object
#  4   industry             1000000 non-null  object
#  5   yearsExperience      1000000 non-null  int64
#  6   milesFromMetropolis  1000000 non-null  int64
#  7   salary               1000000 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 68.7+ MB

# %%
# Check companyId column for invalid inputs
df['companyId'].unique()
# Out:
# array(['COMP37', 'COMP19', 'COMP52', 'COMP38', 'COMP7', 'COMP15',
#        'COMP24', 'COMP20', 'COMP41', 'COMP56', 'COMP4', 'COMP54',
#        'COMP57', 'COMP14', 'COMP61', 'COMP58', 'COMP3', 'COMP44',
#        'COMP30', 'COMP27', 'COMP34', 'COMP11', 'COMP31', 'COMP49',
#        'COMP0', 'COMP1', 'COMP36', 'COMP47', 'COMP8', 'COMP42', 'COMP50',
#        'COMP53', 'COMP48', 'COMP45', 'COMP46', 'COMP2', 'COMP5', 'COMP55',
#        'COMP29', 'COMP40', 'COMP33', 'COMP22', 'COMP12', 'COMP25',
#        'COMP6', 'COMP23', 'COMP17', 'COMP28', 'COMP21', 'COMP26',
#        'COMP43', 'COMP51', 'COMP10', 'COMP59', 'COMP13', 'COMP39',
#        'COMP16', 'COMP9', 'COMP32', 'COMP62', 'COMP35', 'COMP18',
#        'COMP60'], dtype=object)

# %%
# Check jobType column for invalid inputs
df['jobType'].value_counts()
# Out:
# SENIOR            125886
# VICE_PRESIDENT    125235
# MANAGER           125121
# CTO               125046
# JANITOR           124971
# CEO               124778
# JUNIOR            124594
# CFO               124369
# Name: jobType, dtype: int64

# %%
# check degree column for invalid inputs
df['degree'].value_counts()
# Out:
# HIGH_SCHOOL    236976
# NONE           236854
# BACHELORS      175495
# DOCTORAL       175364
# MASTERS        175311
# Name: degree, dtype: int64

# %%
# Check major column for invalid inputs
df['major'].value_counts()
# Out:
# NONE           532355
# CHEMISTRY       58875
# LITERATURE      58684
# ENGINEERING     58596
# BUSINESS        58518
# PHYSICS         58410
# COMPSCI         58382
# BIOLOGY         58379
# MATH            57801
# Name: major, dtype: int64

# %%
# Check industry column for invalid inputs
df['industry'].value_counts()
# Out:
# WEB          143206
# AUTO         142943
# FINANCE      142867
# EDUCATION    142819
# OIL          142771
# HEALTH       142755
# SERVICE      142639
# Name: industry, dtype: int64

# %%
# Check for negative or unrealistic values
df.describe()
# Out:
#        yearsExperience  milesFromMetropolis          salary
# count   1000000.000000       1000000.000000  1000000.000000
# mean         11.992386            49.529260      116.061818
# std           7.212391            28.877733       38.717936
# min           0.000000             0.000000        0.000000
# 25%           6.000000            25.000000       88.000000
# 50%          12.000000            50.000000      114.000000
# 75%          18.000000            75.000000      141.000000
# max          24.000000            99.000000      301.000000

# %%
# Explore the upper and lower quartiles of the target
dataset = df.salary.describe()
print(dataset)
IQR = dataset['75%']-dataset['25%']
upperlimit = dataset['75%'] + (1.5*IQR)
lowerlimit = dataset['25%'] - (1.5*IQR)
print("The upper outlier limit is", upperlimit)
print("The lower outlier limit is", lowerlimit)
# Out:
# count    1000000.000000
# mean         116.061818
# std           38.717936
# min            0.000000
# 25%           88.000000
# 50%          114.000000
# 75%          141.000000
# max          301.000000
# Name: salary, dtype: float64
# The upper outlier limit is 220.5
# The lower outlier limit is 8.5

# %%
# Explore the outliers at the lower end of the salary distribution
df.loc[df.salary < lowerlimit]
# Out:
#        companyId         jobType       degree        major industry  \
# 30559     COMP44          JUNIOR     DOCTORAL         MATH     AUTO
# 495984    COMP34          JUNIOR         NONE         NONE      OIL
# 652076    COMP25             CTO  HIGH_SCHOOL         NONE     AUTO
# 816129    COMP42         MANAGER     DOCTORAL  ENGINEERING  FINANCE
# 828156    COMP40  VICE_PRESIDENT      MASTERS  ENGINEERING      WEB
#
#         yearsExperience  milesFromMetropolis  salary
# 30559                11                    7       0
# 495984                1                   25       0
# 652076                6                   60       0
# 816129               18                    6       0
# 828156                3                   29       0

# %% [markdown]
# **The lower limit outliers are $0 salaries. Since these targets do not contribute to the purpose of the model, its better to exclude them.**

# %%
# Drop entries where posted salary = $0
df = df[df['salary'] > lowerlimit]
df.shape
# Out:
# (999995, 8)

# %%
# Explore the outliers at the upper end of the salary distribution
df.loc[df.salary > upperlimit, 'jobType'].value_counts()
# Out:
# CEO               3227
# CFO               1496
# CTO               1488
# VICE_PRESIDENT     603
# MANAGER            217
# SENIOR              66
# JUNIOR              20
# Name: jobType, dtype: int64

# %% [markdown]
# **Most positions with a salary above the upper limit are of high rank so they are acceptable, except for Junior positions which will be explored more.**

# %%
# Explore the outliers at the upper end of the salary distribution where job level is listed as 'Junior'
df[(df.salary > upperlimit) & (df.jobType == 'JUNIOR')]
# Out:
#        companyId jobType     degree        major industry  yearsExperience  \
# 1222      COMP40  JUNIOR    MASTERS      COMPSCI      OIL               24
# 27710     COMP21  JUNIOR   DOCTORAL  ENGINEERING      OIL               24
# 31355     COMP45  JUNIOR   DOCTORAL      COMPSCI  FINANCE               24
# 100042    COMP17  JUNIOR   DOCTORAL     BUSINESS  FINANCE               23
# 160333    COMP18  JUNIOR   DOCTORAL     BUSINESS  FINANCE               22
# 189582    COMP32  JUNIOR   DOCTORAL     BUSINESS      OIL               24
# 214606    COMP47  JUNIOR    MASTERS     BUSINESS  FINANCE               22
# 303778    COMP51  JUNIOR    MASTERS  ENGINEERING      WEB               24
# 348354    COMP56  JUNIOR   DOCTORAL  ENGINEERING      OIL               23
# 427593    COMP54  JUNIOR   DOCTORAL  ENGINEERING  FINANCE               23
# 500739    COMP40  JUNIOR   DOCTORAL  ENGINEERING      OIL               21
# 627534     COMP5  JUNIOR   DOCTORAL  ENGINEERING      OIL               24
# 645555    COMP36  JUNIOR   DOCTORAL     BUSINESS  FINANCE               24
# 656572    COMP28  JUNIOR   DOCTORAL     BUSINESS      OIL               22
# 685775    COMP38  JUNIOR  BACHELORS  ENGINEERING      OIL               24
# 743326    COMP14  JUNIOR   DOCTORAL     BUSINESS  FINANCE               19
# 787674    COMP43  JUNIOR   DOCTORAL     BUSINESS  FINANCE               18
# 796956    COMP30  JUNIOR    MASTERS     BUSINESS      OIL               24
# 855219    COMP13  JUNIOR    MASTERS  ENGINEERING      OIL               22
# 954368    COMP11  JUNIOR   DOCTORAL     BUSINESS      OIL               24
#
#         milesFromMetropolis  salary
# 1222                      5     225
# 27710                     3     246
# 31355                     0     225
# 100042                    8     248
# 160333                    3     223
# 189582                   11     221
# 214606                    4     222
# 303778                    2     226
# 348354                   25     226
# 427593                    3     221
# 500739                    0     227
# 627534                   29     230
# 645555                    1     225
# 656572                    3     222
# 685775                   13     225
# 743326                    0     236
# 787674                   15     232
# 796956                    2     228
# 855219                   26     225
# 954368                   26     223

# %% [markdown]
# **The majority of Junior positions require advanced degrees and are for jobs in the Oil and Finance industry. Since these are highly paid industry, these outliers are acceptable.**

# %% [markdown]
# ### ---- Explore the data (EDA) ----

# %% [markdown]
# **Summarize each variable and look for correlation between features & each feature and the target.**

# %%
# Explore the target variable, salary
plt.figure(figsize=(15, 7))
plt.subplot(1, 2, 1)
sns.boxplot(df.salary)
plt.subplot(1, 2, 2)
sns.distplot(df.salary, bins=30)
plt.show()

# %%
# Function that creates plots to eplore the feature variables
def plot_features(df, var): 
    '''
    produce plot for each features
    plot1(left), the distribution of samples on the feature
    plot2(right), the dependance of salary on the feature
    '''
    plt.figure(figsize = (17, 4))
    plt.subplot(1, 2, 1)
    if df[var].dtype == 'int64':
        plt.hist(df[var], bins=5)
    else:
        #change the object datatype of each variable to category type and order their level by the mean salary
        mean = df.groupby(var)["salary"].mean()
        df[var] = df[var].astype('category')
        level = mean.sort_values().index.tolist()
        df[var].cat.reorder_categories(level, inplace=True)
        df[var].value_counts().plot(kind='bar')   
    plt.xticks(rotation=90, size=8)
    plt.xlabel(var)
    plt.ylabel('Count')
    
    plt.subplot(1, 2, 2)
    #There are many different companyIds so its better to visualize with a line graph
    if df[var].dtype == 'int64' or var == "companyId": 
        #Plot the mean salary for each category and shade the line between the (mean - std, mean + std)
        mean = df.groupby(var)["salary"].mean()
        std = df.groupby(var)["salary"].std()
        mean.plot()
        plt.fill_between(range(len(std.index)), mean.values-std.values, mean.values + std.values,alpha = 0.1)
    else:
        sns.boxplot(x= var, y="salary", data= df)
    
    plt.xticks(rotation=90)
    plt.ylabel('Salary')
    plt.show()

# %%
plot_features(df, "companyId")
# Out:
# C:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
plot_features(df, "jobType")

# %%
plot_features(df, "degree")

# %%
plot_features(df, "major")

# %%
plot_features(df, "industry")

# %%
plot_features(df, "yearsExperience")

# %%
plot_features(df, "milesFromMetropolis")

# %%
# Function for encoding categorical data in a dataframe
def Encode_Data(df):    
    for col in df.columns:
        if df[col].dtype.name == 'category':
            le = LabelEncoder()
            df[col] = le.fit_transform(df[col])
    return df

# %%
# Create copy of dataframe and encode the categorical data
df_baseline = df.copy()
df_baseline = Encode_Data(df_baseline)

# %%
# Plot seaborn heatmap to visualize correlation between variables
plt.figure(figsize = (11, 8))
corr = df_baseline.corr()
sns.heatmap(corr,
            xticklabels = corr.columns.values,
            yticklabels = corr.columns.values,cmap = "magma", vmin=-1, vmax=1, annot=True, linewidths=1)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# **Upon analyzation of the above graphs and heatmap, it looks like years experience and miles from metropolis are the features most correlated with salary. There are also no signs of collinearity between existing features. Company ID has almost zero correlation with salary and its removal from the final training set will be considered, but for now it will be included in the baseline model.**

# %% [markdown]
# ### ---- Establish a baseline ----

# %% [markdown]
# **Build a simple baseline model to track improvements.**

# %%
# Return feature column names
df_baseline.columns
# Out:
# Index(['companyId', 'jobType', 'degree', 'major', 'industry',
#        'yearsExperience', 'milesFromMetropolis', 'salary'],
#       dtype='object')

# %%
# Split features and targets into two separate dataframes
df_features_baseline = df_baseline[['companyId','jobType', 'degree', 'major', 'industry',
       'yearsExperience', 'milesFromMetropolis']]
df_targets_baseline = df_baseline[['salary']]
del df_baseline

# %%
# Fit a very basic linear model and calculate its MSE
lr = LinearRegression()
lr_baseline_mse = cross_val_score(lr, df_features_baseline, df_targets_baseline, scoring = 'neg_mean_squared_error')
lr_baseline_mse = -1*lr_baseline_mse.mean()
print("Baseline MSE Score: ", lr_baseline_mse)
# Out:
# Baseline MSE Score:  925.1195135463097

# %% [markdown]
# **Additional models, hyperparameter tuning, and feature engineering will be utilized to reduce this baseline MSE, of about 925, to roughly one-third of this value.**

# %% [markdown]
# ### ---- Hypothesize solution ----

# %% [markdown]
# **Models expected to return better accuracy than the baseline linear model:**
# - Stochastic Gradient Descent - Works well with large number of observations (>100K), may show improvement over linear regressor.
# - Decision Tree - The data is simple enough for binary splitting.
# - Random Forest - If moving forward with dummy encoding and creating more variables, this algorithm could provide higher accuracy over decision tree.
# - Xgboost - Powerful boosting esemble that can optimize on least squares regression.
#
# **Feature engineering explored in an effort to achieve a better accuracy over the baseline linear model:**
# - Both ordinal encoding and dummy encoding were explored. They both resulted in a better mse score, but dummy encoding was superior. Dummy encoding of the categorical features and min-max scaling of the continuous features (for SGD model) will be utilized.
# - Changing observations with degree != 'NONE' and major = 'NONE' to major = 'ANY' in order to distinguish between no degree / no major and degree / no major. This did not result in a better mse score.
# - Binning together degree = 'NONE' and degree = 'HIGH_SCHOOL'. This did not result in a better mse score.
# - Binning degree into two categories: no_degree and degree. This did not result in a better mse score.
# - Binning both years experience and miles from metropolis. Niether method resulted in a better mse score.

# %% [markdown]
# ## Part 3 - DEVELOP

# %% [markdown]
# ### ----  Engineer features  ----

# %%
# Place categorical features into a separate dataframe dummy encoding - excluding company ID from the model
df_categories = df[['jobType', 'degree', 'major', 'industry']]
df_categories = pd.get_dummies(df_categories, drop_first=True)

# %%
df_categories.shape
# Out:
# (999995, 25)

# %%
# Scale numerical features to values between 0 and 1 for SGD algorithm
df_continuous = df[['yearsExperience','milesFromMetropolis']]
cols = df_continuous.columns
df_continuous = MinMaxScaler().fit_transform(df_continuous)
df_continuous = pd.DataFrame(df_continuous, columns = cols)

# %%
# Combine transformed categorical features and numerical features
df_features = pd.concat([df_categories.reset_index(drop=True), df_continuous], axis=1)
df_targets = df[['salary']]
del df_categories, df_continuous

# %%
df_features.shape
# Out:
# (999995, 27)

# %% [markdown]
# ### ---- Create, test and select best model ----

# %%
# Function for determining the 5F-CV MSE of each individual model
def evaluate_model(model):
    neg_mse = cross_val_score(model, df_features, df_targets.values.ravel(), scoring='neg_mean_squared_error')
    mse = -1 * neg_mse
    std_mse = round(mse.std(), 2)
    mean_mse = round(mse.mean(), 2)
    print("\nModel:\n", model)
    print("    Standard Deviation of Cross Validation MSEs:\n    ", std_mse)
    print("    Mean 5-Fold Cross Validation MSE:\n    ", mean_mse)
    return mean_mse

# %%
# Loop through different models and obtain each corresponding mse. Hyperparameters have been chosen through manual testing.
models = []
mean_mse = {}

lr = LinearRegression()

sgd = SGDRegressor(max_iter=200, learning_rate='optimal')

dtr = DecisionTreeRegressor(max_depth=15)

rf = RandomForestRegressor(n_estimators=150, n_jobs=-1, max_depth=30, min_samples_split=60, max_features='sqrt')

xgb = xgboost.XGBRegressor(max_depth=5, n_estimators=500, learning_rate=0.1, n_jobs=-1)

models.extend([lr, sgd, dtr, rf, xgb])

print("Starting Cross Validation of Models...\n")

for model in models:
    mse_iter = evaluate_model(model)
    mean_mse.update({model:mse_iter})
    
best_model = min(mean_mse, key=mean_mse.get)
    
print("\n\nThe model with the lowest average MSE to use for predictions is:\n")
print(best_model)
# Out:
# Starting Cross Validation of Models...
#
#
# Model:
#  LinearRegression()
#     Standard Deviation of Cross Validation MSEs:
#      1.78
#     Mean 5-Fold Cross Validation MSE:
#      384.41
#
# Model:
#  SGDRegressor(learning_rate='optimal', max_iter=200)
#     Standard Deviation of Cross Validation MSEs:
#      1.79
#     Mean 5-Fold Cross Validation MSE:
#      384.55
#
# Model:
#  DecisionTreeRegressor(max_depth=15)
#     Standard Deviation of Cross Validation MSEs:
#      1.89
#     Mean 5-Fold Cross Validation MSE:
#      433.27
#
# Model:
#  RandomForestRegressor(max_depth=30, max_features='sqrt', min_samples_split=60,
#                       n_estimators=150, n_jobs=-1)
#     Standard Deviation of Cross Validation MSEs:
#      1.65
#     Mean 5-Fold Cross Validation MSE:
#      372.17
# [21:14:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:17:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:19:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:22:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:25:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#
# Model:
#  XGBRegressor(max_depth=5, n_estimators=500, n_jobs=-1)
#     Standard Deviation of Cross Validation MSEs:
#      1.34
#     Mean 5-Fold Cross Validation MSE:
#      356.62
#
#
# The model with the lowest average MSE to use for predictions is:
#
# XGBRegressor(max_depth=5, n_estimators=500, n_jobs=-1)

# %%
# Create pandas dataframe from the mean_mse dictionary
models_df = pd.DataFrame.from_dict(data = mean_mse, orient='index', columns=['MSE-Score'])
models_df.index = ['LR', 'SDG', 'DTR', 'RF', 'XGB']
models_df
# Out:
#      MSE-Score
# LR      384.41
# SDG     384.55
# DTR     433.27
# RF      372.17
# XGB     356.62

# %%
# Plot bar chart of model accuracy results
models_df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ---- Fine-tune best model ----

# %% [markdown]
# **To fine-tune the XGBoost estimator, different n_estimators, max_depth, and learning_rate values will be explored through further testing.**

# %%
# Split training data into training and testing dataframes for use in grid search function
X_train, X_test, y_train, y_test = train_test_split(df_features, df_targets, random_state=36, test_size=0.2)

# %%
# Create empty array to store results
results = []

# Create watchlist to keep track of train/validation performance
eval_set = [(X_train, y_train), (X_test, y_test)]

# %%
# Check default hyperparameters of XGBoost Regressor
print(inspect.signature(xgboost.XGBRegressor))
# Out:
# (max_depth=3, learning_rate=0.1, n_estimators=100, verbosity=1, silent=None, objective='reg:linear', booster='gbtree', n_jobs=1, nthread=None, gamma=0, min_child_weight=1, max_delta_step=0, subsample=1, colsample_bytree=1, colsample_bylevel=1, colsample_bynode=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1, base_score=0.5, random_state=0, seed=None, missing=None, importance_type='gain', **kwargs)

# %%
# Reset results array
results = []

# Enumerate through different n_estimators values and store results
for n_estimators in [100, 150, 250, 500, 750, 1000]:
    clf = xgboost.XGBRegressor(max_depth=5, learning_rate=0.1, n_estimators=n_estimators, n_jobs=-1)
    clf.fit(X_train, y_train, eval_set=eval_set, verbose=False)
    results.append(
        {
            'n_estimators': n_estimators,
            'train_error': metrics.mean_squared_error(y_train, clf.predict(X_train)),
            'test_error': metrics.mean_squared_error(y_test, clf.predict(X_test))
        })

# Display Results
n_estimators_lr = pd.DataFrame(results).set_index('n_estimators').sort_index()
n_estimators_lr
# Out:
# [21:28:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#               train_error  test_error
# n_estimators
# 100            371.127086  370.351965
# 150            360.342180  360.007623
# 250            355.473944  355.823650
# 500            352.485315  354.533156
# 750            350.818615  354.412795
# 1000           349.442958  354.417789

# %%
# Plot N_Estimators Rate Learning Curve
n_estimators_lr.plot(title="N_Estimators Learning Curve")
# Out:
# <AxesSubplot:title={'center':'N_Estimators Learning Curve'}, xlabel='n_estimators'>

# %% [markdown]
# **It looks like the optimal n_estimators value is 500 or greater while max_depth = 5 and learning_rate = 0.1.**

# %%
# Reset results array
results = []

# Enumerate through different max_depth values and store results
for max_depth in [3, 4, 5, 6, 8, 10]:
    clf = xgboost.XGBRegressor(max_depth=max_depth, n_estimators=750, learning_rate=0.1, n_jobs=-1)
    clf.fit(X_train, y_train, eval_set=eval_set, verbose=False)
    results.append(
        {
            'max_depth': max_depth,
            'train_error': metrics.mean_squared_error(y_train, clf.predict(X_train)),
            'test_error': metrics.mean_squared_error(y_test, clf.predict(X_test))
        })
    
# Display Results
max_depth_lr = pd.DataFrame(results).set_index('max_depth').sort_index()
max_depth_lr
# Out:
# [21:45:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:48:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:52:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:56:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:02:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:10:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#            train_error  test_error
# max_depth
# 3           355.795346  354.367711
# 4           354.073766  354.009156
# 5           350.818615  354.412795
# 6           345.139602  355.553698
# 8           318.314143  361.335433
# 10          260.970582  376.796722

# %%
# Plot Max_Depth Learning Curve
max_depth_lr.plot(title="Max_Depth Learning Curve")
# Out:
# <AxesSubplot:title={'center':'Max_Depth Learning Curve'}, xlabel='max_depth'>

# %% [markdown]
# **It looks like the optimal max_depth value is around 4 while n_estimators = 750 and learning_rate = 0.1 as the test_error curve begins to diverge from the train_error curve at that point.**

# %%
# Reset results array
results = []

# Enumerate through different learning_rate values and store results
for learning_rate in [0.05, 0.1, 0.2, 0.3]:
    clf = xgboost.XGBRegressor(max_depth=4, learning_rate=learning_rate, n_estimators=750, n_jobs=-1)
    clf.fit(X_train, y_train, eval_set=eval_set, verbose=False)
    results.append(
        {
            'learning_rate': learning_rate,
            'train_error': metrics.mean_squared_error(y_train, clf.predict(X_train)),
            'test_error': metrics.mean_squared_error(y_test, clf.predict(X_test))
        })
    
# Display Results    
learning_rate_lr = pd.DataFrame(results).set_index('learning_rate').sort_index()
learning_rate_lr
# Out:
# [22:20:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:23:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:27:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:31:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                train_error  test_error
# learning_rate
# 0.05            355.565790  354.624322
# 0.10            354.073766  354.009156
# 0.20            352.762697  354.413865
# 0.30            351.212361  354.194263

# %%
# Plot Learning Rate Learning Curve
learning_rate_lr.plot(title="Learning Rate Learning Curve")
# Out:
# <AxesSubplot:title={'center':'Learning Rate Learning Curve'}, xlabel='learning_rate'>

# %% [markdown]
# **It looks like the optimal learning_rate value could be between 0.05 and 0.10 while max_depth=4 and n_estimators=750. It's possible that the model with learning_rate=0.05 was unable to converge, therefore we will explore early stopping with this learning rate.**

# %%
# Save best hyperparameter setting
best_model = xgboost.XGBRegressor(learning_rate=0.05, max_depth=4, n_estimators=2000, n_jobs=-1)

# %%
# Fit the training set and apply early stopping 
best_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set
# [42]	validation_0-rmse:29.0038	validation_1-rmse:28.9509
# [43]	validation_0-rmse:28.5521	validation_1-rmse:28.4975
# [44]	validation_0-rmse:28.195	validation_1-rmse:28.1416
# [45]	validation_0-rmse:27.8658	validation_1-rmse:27.8139
# [46]	validation_0-rmse:27.4932	validation_1-rmse:27.4397
# [47]	validation_0-rmse:27.1688	validation_1-rmse:27.1161
# [48]	validation_0-rmse:26.8689	validation_1-rmse:26.8173
# [49]	validation_0-rmse:26.6194	validation_1-rmse:26.5677
# [50]	validation_0-rmse:26.3291	validation_1-rmse:26.2766
# [51]	validation_0-rmse:26.0994	validation_1-rmse:26.049
# [52]	validation_0-rmse:25.8987	validation_1-rmse:25.8479
# [53]	validation_0-rmse:25.7066	validation_1-rmse:25.6559
# [54]	validation_0-rmse:25.4918	validation_1-rmse:25.4401
# [55]	validation_0-rmse:25.2929	validation_1-rmse:25.2419
# [56]	validation_0-rmse:25.1181	validation_1-rmse:25.0671
# [57]	validation_0-rmse:24.9551	validation_1-rmse:24.9047
# [58]	validation_0-rmse:24.8013	validation_1-rmse:24.7501
# [59]	validation_0-rmse:24.6401	validation_1-rmse:24.5898
# [60]	validation_0-rmse:24.4689	validation_1-rmse:24.4172
# [61]	validation_0-rmse:24.3473	validation_1-rmse:24.2965
# [62]	validation_0-rmse:24.2267	validation_1-rmse:24.1778
# [63]	validation_0-rmse:24.109	validation_1-rmse:24.0603
# [64]	validation_0-rmse:23.9655	validation_1-rmse:23.9165
# [65]	validation_0-rmse:23.8297	validation_1-rmse:23.7792
# [66]	validation_0-rmse:23.7129	validation_1-rmse:23.6637
# [67]	validation_0-rmse:23.588	validation_1-rmse:23.5377
# [68]	validation_0-rmse:23.5049	validation_1-rmse:23.4545
# [69]	validation_0-rmse:23.4164	validation_1-rmse:23.3661
# [70]	validation_0-rmse:23.3169	validation_1-rmse:23.2672
# [71]	validation_0-rmse:23.2084	validation_1-rmse:23.158
# [72]	validation_0-rmse:23.1272	validation_1-rmse:23.0787
# [73]	validation_0-rmse:23.06	validation_1-rmse:23.0121
# [74]	validation_0-rmse:22.9631	validation_1-rmse:22.9138
# [75]	validation_0-rmse:22.8923	validation_1-rmse:22.8435
# [76]	validation_0-rmse:22.8133	validation_1-rmse:22.7654
# [77]	validation_0-rmse:22.7333	validation_1-rmse:22.6856
# [78]	validation_0-rmse:22.6493	validation_1-rmse:22.6007
# [79]	validation_0-rmse:22.5955	validation_1-rmse:22.5468
# [80]	validation_0-rmse:22.5179	validation_1-rmse:22.468
# [81]	validation_0-rmse:22.4615	validation_1-rmse:22.4121
# [82]	validation_0-rmse:22.3952	validation_1-rmse:22.3462
# [83]	validation_0-rmse:22.3297	validation_1-rmse:22.2814
# [84]	validation_0-rmse:22.2855	validation_1-rmse:22.2368
# [85]	validation_0-rmse:22.2435	validation_1-rmse:22.1951
# [86]	validation_0-rmse:22.1856	validation_1-rmse:22.1378
# [87]	validation_0-rmse:22.1206	validation_1-rmse:22.0728
# [88]	validation_0-rmse:22.0588	validation_1-rmse:22.0105
# [89]	validation_0-rmse:22.0004	validation_1-rmse:21.9513
# [90]	validation_0-rmse:21.9488	validation_1-rmse:21.9005
# [91]	validation_0-rmse:21.9132	validation_1-rmse:21.865
# [92]	validation_0-rmse:21.8716	validation_1-rmse:21.8233
# [93]	validation_0-rmse:21.8183	validation_1-rmse:21.7691
# [94]	validation_0-rmse:21.7724	validation_1-rmse:21.7237
# [95]	validation_0-rmse:21.7376	validation_1-rmse:21.6892
# [96]	validation_0-rmse:21.7053	validation_1-rmse:21.6571
# [97]	validation_0-rmse:21.6682	validation_1-rmse:21.6206
# [98]	validation_0-rmse:21.6289	validation_1-rmse:21.5808
# [99]	validation_0-rmse:21.601	validation_1-rmse:21.5532
# [100]	validation_0-rmse:21.5568	validation_1-rmse:21.5084
# [101]	validation_0-rmse:21.5176	validation_1-rmse:21.4697
# [102]	validation_0-rmse:21.4758	validation_1-rmse:21.4275
# [103]	validation_0-rmse:21.4505	validation_1-rmse:21.402
# [104]	validation_0-rmse:21.4191	validation_1-rmse:21.3709
# [105]	validation_0-rmse:21.3846	validation_1-rmse:21.3365
# [106]	validation_0-rmse:21.3604	validation_1-rmse:21.3123
# [107]	validation_0-rmse:21.3369	validation_1-rmse:21.2892
# [108]	validation_0-rmse:21.2992	validation_1-rmse:21.2509
# [109]	validation_0-rmse:21.2634	validation_1-rmse:21.2146
# [110]	validation_0-rmse:21.236	validation_1-rmse:21.1874
# [111]	validation_0-rmse:21.2046	validation_1-rmse:21.1562
# [112]	validation_0-rmse:21.1837	validation_1-rmse:21.1354
# [113]	validation_0-rmse:21.1624	validation_1-rmse:21.1144
# [114]	validation_0-rmse:21.1342	validation_1-rmse:21.0865
# [115]	validation_0-rmse:21.1015	validation_1-rmse:21.0532
# [116]	validation_0-rmse:21.0717	validation_1-rmse:21.0236
# [117]	validation_0-rmse:21.0536	validation_1-rmse:21.0058
# [118]	validation_0-rmse:21.0231	validation_1-rmse:20.9748
# [119]	validation_0-rmse:20.9941	validation_1-rmse:20.9455
# [120]	validation_0-rmse:20.9729	validation_1-rmse:20.9246
# [121]	validation_0-rmse:20.9474	validation_1-rmse:20.8994
# [122]	validation_0-rmse:20.9259	validation_1-rmse:20.8781
# [123]	validation_0-rmse:20.9089	validation_1-rmse:20.8615
# [124]	validation_0-rmse:20.8815	validation_1-rmse:20.8335
# [125]	validation_0-rmse:20.8547	validation_1-rmse:20.8066
# [126]	validation_0-rmse:20.8338	validation_1-rmse:20.7858
# [127]	validation_0-rmse:20.8178	validation_1-rmse:20.7699
# [128]	validation_0-rmse:20.7946	validation_1-rmse:20.7465
# [129]	validation_0-rmse:20.7694	validation_1-rmse:20.7213
# [130]	validation_0-rmse:20.7443	validation_1-rmse:20.6961
# [131]	validation_0-rmse:20.7296	validation_1-rmse:20.6814
# [132]	validation_0-rmse:20.7083	validation_1-rmse:20.6606
# [133]	validation_0-rmse:20.6911	validation_1-rmse:20.6435
# [134]	validation_0-rmse:20.6731	validation_1-rmse:20.6256
# [135]	validation_0-rmse:20.6503	validation_1-rmse:20.6029
# [136]	validation_0-rmse:20.6277	validation_1-rmse:20.5802
# [137]	validation_0-rmse:20.6131	validation_1-rmse:20.5655
# [138]	validation_0-rmse:20.5936	validation_1-rmse:20.5458
# [139]	validation_0-rmse:20.5807	validation_1-rmse:20.5328
# [140]	validation_0-rmse:20.5601	validation_1-rmse:20.5118
# [141]	validation_0-rmse:20.5396	validation_1-rmse:20.4913
# [142]	validation_0-rmse:20.5236	validation_1-rmse:20.4755
# [143]	validation_0-rmse:20.5109	validation_1-rmse:20.4631
# [144]	validation_0-rmse:20.4952	validation_1-rmse:20.4478
# [145]	validation_0-rmse:20.4755	validation_1-rmse:20.4284
# [146]	validation_0-rmse:20.4618	validation_1-rmse:20.4145
# [147]	validation_0-rmse:20.4434	validation_1-rmse:20.3965
# [148]	validation_0-rmse:20.4303	validation_1-rmse:20.3834
# [149]	validation_0-rmse:20.411	validation_1-rmse:20.3646
# [150]	validation_0-rmse:20.3932	validation_1-rmse:20.3467
# [151]	validation_0-rmse:20.3758	validation_1-rmse:20.3291
# [152]	validation_0-rmse:20.3634	validation_1-rmse:20.3173
# [153]	validation_0-rmse:20.3501	validation_1-rmse:20.3042
# [154]	validation_0-rmse:20.3406	validation_1-rmse:20.2945
# [155]	validation_0-rmse:20.3231	validation_1-rmse:20.2767
# [156]	validation_0-rmse:20.3134	validation_1-rmse:20.2671
# [157]	validation_0-rmse:20.297	validation_1-rmse:20.2505
# [158]	validation_0-rmse:20.2809	validation_1-rmse:20.2346
# [159]	validation_0-rmse:20.2678	validation_1-rmse:20.2214
# [160]	validation_0-rmse:20.2526	validation_1-rmse:20.2063
# [161]	validation_0-rmse:20.2439	validation_1-rmse:20.1977
# [162]	validation_0-rmse:20.2315	validation_1-rmse:20.1852
# [163]	validation_0-rmse:20.2171	validation_1-rmse:20.1706
# [164]	validation_0-rmse:20.2027	validation_1-rmse:20.1563
# [165]	validation_0-rmse:20.1889	validation_1-rmse:20.1426
# [166]	validation_0-rmse:20.1748	validation_1-rmse:20.1284
# [167]	validation_0-rmse:20.1655	validation_1-rmse:20.1192
# [168]	validation_0-rmse:20.1573	validation_1-rmse:20.1109
# [169]	validation_0-rmse:20.1453	validation_1-rmse:20.0987
# [170]	validation_0-rmse:20.1322	validation_1-rmse:20.0858
# [171]	validation_0-rmse:20.1169	validation_1-rmse:20.0708
# [172]	validation_0-rmse:20.1043	validation_1-rmse:20.058
# [173]	validation_0-rmse:20.0957	validation_1-rmse:20.0498
# [174]	validation_0-rmse:20.0888	validation_1-rmse:20.0431
# [175]	validation_0-rmse:20.08	validation_1-rmse:20.0342
# [176]	validation_0-rmse:20.0676	validation_1-rmse:20.022
# [177]	validation_0-rmse:20.0557	validation_1-rmse:20.01
# [178]	validation_0-rmse:20.0436	validation_1-rmse:19.9977
# [179]	validation_0-rmse:20.0344	validation_1-rmse:19.9883
# [180]	validation_0-rmse:20.0255	validation_1-rmse:19.9798
# [181]	validation_0-rmse:20.0144	validation_1-rmse:19.969
# [182]	validation_0-rmse:20.0031	validation_1-rmse:19.9575
# [183]	validation_0-rmse:19.9966	validation_1-rmse:19.9511
# [184]	validation_0-rmse:19.9857	validation_1-rmse:19.9404
# [185]	validation_0-rmse:19.974	validation_1-rmse:19.9287
# [186]	validation_0-rmse:19.967	validation_1-rmse:19.922
# [187]	validation_0-rmse:19.956	validation_1-rmse:19.9113
# [188]	validation_0-rmse:19.9457	validation_1-rmse:19.901
# [189]	validation_0-rmse:19.9353	validation_1-rmse:19.8905
# [190]	validation_0-rmse:19.9254	validation_1-rmse:19.8807
# [191]	validation_0-rmse:19.9144	validation_1-rmse:19.8697
# [192]	validation_0-rmse:19.9048	validation_1-rmse:19.8604
# [193]	validation_0-rmse:19.8974	validation_1-rmse:19.853
# [194]	validation_0-rmse:19.89	validation_1-rmse:19.8457
# [195]	validation_0-rmse:19.8815	validation_1-rmse:19.8374
# [196]	validation_0-rmse:19.8753	validation_1-rmse:19.8313
# [197]	validation_0-rmse:19.8658	validation_1-rmse:19.822
# [198]	validation_0-rmse:19.8558	validation_1-rmse:19.8118
# [199]	validation_0-rmse:19.8463	validation_1-rmse:19.8025
# [200]	validation_0-rmse:19.8366	validation_1-rmse:19.7931
# [201]	validation_0-rmse:19.8267	validation_1-rmse:19.7828
# [202]	validation_0-rmse:19.8179	validation_1-rmse:19.7739
# [203]	validation_0-rmse:19.8086	validation_1-rmse:19.765
# [204]	validation_0-rmse:19.8001	validation_1-rmse:19.7562
# [205]	validation_0-rmse:19.7946	validation_1-rmse:19.751
# [206]	validation_0-rmse:19.7864	validation_1-rmse:19.7428
# [207]	validation_0-rmse:19.7781	validation_1-rmse:19.7345
# [208]	validation_0-rmse:19.7722	validation_1-rmse:19.7288
# [209]	validation_0-rmse:19.7654	validation_1-rmse:19.7223
# [210]	validation_0-rmse:19.7595	validation_1-rmse:19.7167
# [211]	validation_0-rmse:19.7501	validation_1-rmse:19.7071
# [212]	validation_0-rmse:19.742	validation_1-rmse:19.699
# [213]	validation_0-rmse:19.7334	validation_1-rmse:19.6903
# [214]	validation_0-rmse:19.7288	validation_1-rmse:19.6858
# [215]	validation_0-rmse:19.7206	validation_1-rmse:19.6776
# [216]	validation_0-rmse:19.7125	validation_1-rmse:19.6697
# [217]	validation_0-rmse:19.7049	validation_1-rmse:19.6621
# [218]	validation_0-rmse:19.6997	validation_1-rmse:19.6569
# [219]	validation_0-rmse:19.6919	validation_1-rmse:19.6491
# [220]	validation_0-rmse:19.6835	validation_1-rmse:19.6404
# [221]	validation_0-rmse:19.6761	validation_1-rmse:19.6332
# [222]	validation_0-rmse:19.6691	validation_1-rmse:19.6261
# [223]	validation_0-rmse:19.6622	validation_1-rmse:19.6194
# [224]	validation_0-rmse:19.6549	validation_1-rmse:19.612
# [225]	validation_0-rmse:19.6498	validation_1-rmse:19.6072
# [226]	validation_0-rmse:19.6417	validation_1-rmse:19.599
# [227]	validation_0-rmse:19.6358	validation_1-rmse:19.5933
# [228]	validation_0-rmse:19.631	validation_1-rmse:19.5885
# [229]	validation_0-rmse:19.6238	validation_1-rmse:19.5815
# [230]	validation_0-rmse:19.6181	validation_1-rmse:19.5758
# [231]	validation_0-rmse:19.6114	validation_1-rmse:19.5689
# [232]	validation_0-rmse:19.6019	validation_1-rmse:19.5592
# [233]	validation_0-rmse:19.5957	validation_1-rmse:19.5529
# [234]	validation_0-rmse:19.589	validation_1-rmse:19.5463
# [235]	validation_0-rmse:19.5845	validation_1-rmse:19.5418
# [236]	validation_0-rmse:19.5779	validation_1-rmse:19.5354
# [237]	validation_0-rmse:19.5719	validation_1-rmse:19.5294
# [238]	validation_0-rmse:19.5657	validation_1-rmse:19.5235
# [239]	validation_0-rmse:19.5608	validation_1-rmse:19.5187
# [240]	validation_0-rmse:19.555	validation_1-rmse:19.5126
# [241]	validation_0-rmse:19.5491	validation_1-rmse:19.5069
# [242]	validation_0-rmse:19.5435	validation_1-rmse:19.5015
# [243]	validation_0-rmse:19.5377	validation_1-rmse:19.4954
# [244]	validation_0-rmse:19.5326	validation_1-rmse:19.4905
# [245]	validation_0-rmse:19.5261	validation_1-rmse:19.4838
# [246]	validation_0-rmse:19.5221	validation_1-rmse:19.4799
# [247]	validation_0-rmse:19.5165	validation_1-rmse:19.4744
# [248]	validation_0-rmse:19.511	validation_1-rmse:19.469
# [249]	validation_0-rmse:19.5052	validation_1-rmse:19.463
# [250]	validation_0-rmse:19.5003	validation_1-rmse:19.4581
# [251]	validation_0-rmse:19.4956	validation_1-rmse:19.4537
# [252]	validation_0-rmse:19.4904	validation_1-rmse:19.4486
# [253]	validation_0-rmse:19.485	validation_1-rmse:19.4433
# [254]	validation_0-rmse:19.4796	validation_1-rmse:19.4378
# [255]	validation_0-rmse:19.4763	validation_1-rmse:19.4349
# [256]	validation_0-rmse:19.47	validation_1-rmse:19.4284
# [257]	validation_0-rmse:19.4643	validation_1-rmse:19.4227
# [258]	validation_0-rmse:19.4595	validation_1-rmse:19.418
# [259]	validation_0-rmse:19.454	validation_1-rmse:19.4124
# [260]	validation_0-rmse:19.4508	validation_1-rmse:19.4093
# [261]	validation_0-rmse:19.4461	validation_1-rmse:19.4048
# [262]	validation_0-rmse:19.4415	validation_1-rmse:19.4
# [263]	validation_0-rmse:19.4341	validation_1-rmse:19.3926
# [264]	validation_0-rmse:19.4299	validation_1-rmse:19.3887
# [265]	validation_0-rmse:19.425	validation_1-rmse:19.384
# [266]	validation_0-rmse:19.4205	validation_1-rmse:19.3794
# [267]	validation_0-rmse:19.4158	validation_1-rmse:19.3747
# [268]	validation_0-rmse:19.4112	validation_1-rmse:19.3703
# [269]	validation_0-rmse:19.4064	validation_1-rmse:19.3654
# [270]	validation_0-rmse:19.4024	validation_1-rmse:19.3612
# [271]	validation_0-rmse:19.3981	validation_1-rmse:19.3571
# [272]	validation_0-rmse:19.3936	validation_1-rmse:19.3524
# [273]	validation_0-rmse:19.391	validation_1-rmse:19.3498
# [274]	validation_0-rmse:19.3868	validation_1-rmse:19.3458
# [275]	validation_0-rmse:19.3825	validation_1-rmse:19.3415
# [276]	validation_0-rmse:19.3783	validation_1-rmse:19.3373
# [277]	validation_0-rmse:19.374	validation_1-rmse:19.3331
# [278]	validation_0-rmse:19.3698	validation_1-rmse:19.3287
# [279]	validation_0-rmse:19.3651	validation_1-rmse:19.3239
# [280]	validation_0-rmse:19.3612	validation_1-rmse:19.3201
# [281]	validation_0-rmse:19.3579	validation_1-rmse:19.3167
# [282]	validation_0-rmse:19.3553	validation_1-rmse:19.3142
# [283]	validation_0-rmse:19.3515	validation_1-rmse:19.3107
# [284]	validation_0-rmse:19.3477	validation_1-rmse:19.3068
# [285]	validation_0-rmse:19.3428	validation_1-rmse:19.3019
# [286]	validation_0-rmse:19.339	validation_1-rmse:19.2983
# [287]	validation_0-rmse:19.3364	validation_1-rmse:19.2958
# [288]	validation_0-rmse:19.3327	validation_1-rmse:19.2921
# [289]	validation_0-rmse:19.3291	validation_1-rmse:19.2886
# [290]	validation_0-rmse:19.3255	validation_1-rmse:19.285
# [291]	validation_0-rmse:19.3219	validation_1-rmse:19.2815
# [292]	validation_0-rmse:19.3183	validation_1-rmse:19.2779
# [293]	validation_0-rmse:19.3138	validation_1-rmse:19.2736
# [294]	validation_0-rmse:19.3071	validation_1-rmse:19.2668
# [295]	validation_0-rmse:19.3037	validation_1-rmse:19.2635
# [296]	validation_0-rmse:19.3008	validation_1-rmse:19.2605
# [297]	validation_0-rmse:19.2987	validation_1-rmse:19.2582
# [298]	validation_0-rmse:19.2951	validation_1-rmse:19.2548
# [299]	validation_0-rmse:19.2915	validation_1-rmse:19.2512
# [300]	validation_0-rmse:19.2883	validation_1-rmse:19.248
# [301]	validation_0-rmse:19.2843	validation_1-rmse:19.244
# [302]	validation_0-rmse:19.279	validation_1-rmse:19.2388
# [303]	validation_0-rmse:19.2757	validation_1-rmse:19.2355
# [304]	validation_0-rmse:19.2725	validation_1-rmse:19.2325
# [305]	validation_0-rmse:19.2699	validation_1-rmse:19.2301
# [306]	validation_0-rmse:19.2646	validation_1-rmse:19.2247
# [307]	validation_0-rmse:19.2613	validation_1-rmse:19.2213
# [308]	validation_0-rmse:19.2584	validation_1-rmse:19.2187
# [309]	validation_0-rmse:19.2554	validation_1-rmse:19.2158
# [310]	validation_0-rmse:19.2525	validation_1-rmse:19.2129
# [311]	validation_0-rmse:19.2499	validation_1-rmse:19.2101
# [312]	validation_0-rmse:19.247	validation_1-rmse:19.2073
# [313]	validation_0-rmse:19.2438	validation_1-rmse:19.2041
# [314]	validation_0-rmse:19.2419	validation_1-rmse:19.2021
# [315]	validation_0-rmse:19.2398	validation_1-rmse:19.2001
# [316]	validation_0-rmse:19.2375	validation_1-rmse:19.1978
# [317]	validation_0-rmse:19.2346	validation_1-rmse:19.1951
# [318]	validation_0-rmse:19.2318	validation_1-rmse:19.1924
# [319]	validation_0-rmse:19.2284	validation_1-rmse:19.1889
# [320]	validation_0-rmse:19.2248	validation_1-rmse:19.1854
# [321]	validation_0-rmse:19.222	validation_1-rmse:19.1825
# [322]	validation_0-rmse:19.2192	validation_1-rmse:19.1799
# [323]	validation_0-rmse:19.2162	validation_1-rmse:19.1769
# [324]	validation_0-rmse:19.2133	validation_1-rmse:19.1738
# [325]	validation_0-rmse:19.2105	validation_1-rmse:19.1712
# [326]	validation_0-rmse:19.2088	validation_1-rmse:19.1695
# [327]	validation_0-rmse:19.2061	validation_1-rmse:19.1668
# [328]	validation_0-rmse:19.2034	validation_1-rmse:19.1638
# [329]	validation_0-rmse:19.2008	validation_1-rmse:19.1614
# [330]	validation_0-rmse:19.198	validation_1-rmse:19.1586
# [331]	validation_0-rmse:19.1955	validation_1-rmse:19.1562
# [332]	validation_0-rmse:19.193	validation_1-rmse:19.1537
# [333]	validation_0-rmse:19.1905	validation_1-rmse:19.1513
# [334]	validation_0-rmse:19.1881	validation_1-rmse:19.1488
# [335]	validation_0-rmse:19.185	validation_1-rmse:19.1457
# [336]	validation_0-rmse:19.1826	validation_1-rmse:19.1435
# [337]	validation_0-rmse:19.1799	validation_1-rmse:19.1409
# [338]	validation_0-rmse:19.178	validation_1-rmse:19.1391
# [339]	validation_0-rmse:19.1754	validation_1-rmse:19.1367
# [340]	validation_0-rmse:19.1737	validation_1-rmse:19.135
# [341]	validation_0-rmse:19.1715	validation_1-rmse:19.1328
# [342]	validation_0-rmse:19.1688	validation_1-rmse:19.1302
# [343]	validation_0-rmse:19.165	validation_1-rmse:19.1263
# [344]	validation_0-rmse:19.1625	validation_1-rmse:19.1239
# [345]	validation_0-rmse:19.1592	validation_1-rmse:19.1207
# [346]	validation_0-rmse:19.1577	validation_1-rmse:19.1193
# [347]	validation_0-rmse:19.1555	validation_1-rmse:19.1172
# [348]	validation_0-rmse:19.1533	validation_1-rmse:19.1151
# [349]	validation_0-rmse:19.1509	validation_1-rmse:19.1128
# [350]	validation_0-rmse:19.1486	validation_1-rmse:19.1105
# [351]	validation_0-rmse:19.1462	validation_1-rmse:19.1082
# [352]	validation_0-rmse:19.1441	validation_1-rmse:19.106
# [353]	validation_0-rmse:19.1417	validation_1-rmse:19.1036
# [354]	validation_0-rmse:19.14	validation_1-rmse:19.1021
# [355]	validation_0-rmse:19.1379	validation_1-rmse:19.0997
# [356]	validation_0-rmse:19.1365	validation_1-rmse:19.0984
# [357]	validation_0-rmse:19.1344	validation_1-rmse:19.0964
# [358]	validation_0-rmse:19.1322	validation_1-rmse:19.0942
# [359]	validation_0-rmse:19.1302	validation_1-rmse:19.0923
# [360]	validation_0-rmse:19.1282	validation_1-rmse:19.0902
# [361]	validation_0-rmse:19.1262	validation_1-rmse:19.0884
# [362]	validation_0-rmse:19.1242	validation_1-rmse:19.0863
# [363]	validation_0-rmse:19.1226	validation_1-rmse:19.0848
# [364]	validation_0-rmse:19.1205	validation_1-rmse:19.0828
# [365]	validation_0-rmse:19.1193	validation_1-rmse:19.0816
# [366]	validation_0-rmse:19.1174	validation_1-rmse:19.0797
# [367]	validation_0-rmse:19.1162	validation_1-rmse:19.0785
# [368]	validation_0-rmse:19.1117	validation_1-rmse:19.0741
# [369]	validation_0-rmse:19.1097	validation_1-rmse:19.072
# [370]	validation_0-rmse:19.1079	validation_1-rmse:19.0702
# [371]	validation_0-rmse:19.106	validation_1-rmse:19.0685
# [372]	validation_0-rmse:19.1037	validation_1-rmse:19.0662
# [373]	validation_0-rmse:19.102	validation_1-rmse:19.0645
# [374]	validation_0-rmse:19.0979	validation_1-rmse:19.0604
# [375]	validation_0-rmse:19.0956	validation_1-rmse:19.0581
# [376]	validation_0-rmse:19.0939	validation_1-rmse:19.0565
# [377]	validation_0-rmse:19.0921	validation_1-rmse:19.0547
# [378]	validation_0-rmse:19.0908	validation_1-rmse:19.0535
# [379]	validation_0-rmse:19.0894	validation_1-rmse:19.0521
# [380]	validation_0-rmse:19.0876	validation_1-rmse:19.0503
# [381]	validation_0-rmse:19.0835	validation_1-rmse:19.0463
# [382]	validation_0-rmse:19.0817	validation_1-rmse:19.0446
# [383]	validation_0-rmse:19.0801	validation_1-rmse:19.043
# [384]	validation_0-rmse:19.0789	validation_1-rmse:19.0419
# [385]	validation_0-rmse:19.0761	validation_1-rmse:19.039
# [386]	validation_0-rmse:19.0749	validation_1-rmse:19.0378
# [387]	validation_0-rmse:19.0738	validation_1-rmse:19.0369
# [388]	validation_0-rmse:19.0722	validation_1-rmse:19.0352
# [389]	validation_0-rmse:19.0705	validation_1-rmse:19.0336
# [390]	validation_0-rmse:19.0695	validation_1-rmse:19.0327
# [391]	validation_0-rmse:19.0675	validation_1-rmse:19.0307
# [392]	validation_0-rmse:19.066	validation_1-rmse:19.0293
# [393]	validation_0-rmse:19.0645	validation_1-rmse:19.0277
# [394]	validation_0-rmse:19.061	validation_1-rmse:19.0243
# [395]	validation_0-rmse:19.0594	validation_1-rmse:19.0226
# [396]	validation_0-rmse:19.0579	validation_1-rmse:19.0213
# [397]	validation_0-rmse:19.0561	validation_1-rmse:19.0195
# [398]	validation_0-rmse:19.0545	validation_1-rmse:19.0179
# [399]	validation_0-rmse:19.0531	validation_1-rmse:19.0167
# [400]	validation_0-rmse:19.0516	validation_1-rmse:19.0151
# [401]	validation_0-rmse:19.0505	validation_1-rmse:19.0141
# [402]	validation_0-rmse:19.0495	validation_1-rmse:19.0131
# [403]	validation_0-rmse:19.0478	validation_1-rmse:19.0115
# [404]	validation_0-rmse:19.0464	validation_1-rmse:19.0102
# [405]	validation_0-rmse:19.0449	validation_1-rmse:19.0087
# [406]	validation_0-rmse:19.0439	validation_1-rmse:19.0077
# [407]	validation_0-rmse:19.0424	validation_1-rmse:19.0062
# [408]	validation_0-rmse:19.0406	validation_1-rmse:19.0044
# [409]	validation_0-rmse:19.0392	validation_1-rmse:19.003
# [410]	validation_0-rmse:19.0381	validation_1-rmse:19.0021
# [411]	validation_0-rmse:19.0352	validation_1-rmse:18.9992
# [412]	validation_0-rmse:19.0343	validation_1-rmse:18.9983
# [413]	validation_0-rmse:19.033	validation_1-rmse:18.997
# [414]	validation_0-rmse:19.0316	validation_1-rmse:18.9957
# [415]	validation_0-rmse:19.0288	validation_1-rmse:18.9929
# [1546]	validation_0-rmse:18.7978	validation_1-rmse:18.8005
# [1547]	validation_0-rmse:18.7978	validation_1-rmse:18.8005
# [1548]	validation_0-rmse:18.7977	validation_1-rmse:18.8005
# [1549]	validation_0-rmse:18.7977	validation_1-rmse:18.8005
# [1550]	validation_0-rmse:18.7977	validation_1-rmse:18.8005
# [1551]	validation_0-rmse:18.7976	validation_1-rmse:18.8005
# [1552]	validation_0-rmse:18.7976	validation_1-rmse:18.8004
# [1553]	validation_0-rmse:18.7975	validation_1-rmse:18.8004
# [1554]	validation_0-rmse:18.7975	validation_1-rmse:18.8004
# [1555]	validation_0-rmse:18.7975	validation_1-rmse:18.8004
# [1556]	validation_0-rmse:18.7974	validation_1-rmse:18.8004
# [1557]	validation_0-rmse:18.7974	validation_1-rmse:18.8004
# [1558]	validation_0-rmse:18.7974	validation_1-rmse:18.8005
# [1559]	validation_0-rmse:18.7973	validation_1-rmse:18.8004
# [1560]	validation_0-rmse:18.7973	validation_1-rmse:18.8004
# [1561]	validation_0-rmse:18.7973	validation_1-rmse:18.8004
# [1562]	validation_0-rmse:18.7972	validation_1-rmse:18.8004
# [1563]	validation_0-rmse:18.7972	validation_1-rmse:18.8004
# [1564]	validation_0-rmse:18.7972	validation_1-rmse:18.8004
# [1565]	validation_0-rmse:18.7971	validation_1-rmse:18.8004
# [1566]	validation_0-rmse:18.7971	validation_1-rmse:18.8004
# [1567]	validation_0-rmse:18.797	validation_1-rmse:18.8004
# [1568]	validation_0-rmse:18.797	validation_1-rmse:18.8004
# [1569]	validation_0-rmse:18.797	validation_1-rmse:18.8003
# [1570]	validation_0-rmse:18.7969	validation_1-rmse:18.8003
# [1571]	validation_0-rmse:18.7969	validation_1-rmse:18.8003
# [1572]	validation_0-rmse:18.7968	validation_1-rmse:18.8003
# [1573]	validation_0-rmse:18.7968	validation_1-rmse:18.8002
# [1574]	validation_0-rmse:18.7968	validation_1-rmse:18.8002
# [1575]	validation_0-rmse:18.7967	validation_1-rmse:18.8002
# [1576]	validation_0-rmse:18.7967	validation_1-rmse:18.8002
# [1577]	validation_0-rmse:18.7967	validation_1-rmse:18.8002
# [1578]	validation_0-rmse:18.7966	validation_1-rmse:18.8002
# [1579]	validation_0-rmse:18.7966	validation_1-rmse:18.8002
# [1580]	validation_0-rmse:18.7965	validation_1-rmse:18.8001
# [1581]	validation_0-rmse:18.7965	validation_1-rmse:18.8001
# [1582]	validation_0-rmse:18.7964	validation_1-rmse:18.8001
# [1583]	validation_0-rmse:18.7964	validation_1-rmse:18.8001
# [1584]	validation_0-rmse:18.7963	validation_1-rmse:18.8001
# [1585]	validation_0-rmse:18.7963	validation_1-rmse:18.8001
# [1586]	validation_0-rmse:18.7963	validation_1-rmse:18.8001
# [1587]	validation_0-rmse:18.7962	validation_1-rmse:18.8001
# [1588]	validation_0-rmse:18.7962	validation_1-rmse:18.8001
# [1589]	validation_0-rmse:18.7962	validation_1-rmse:18.8001
# [1590]	validation_0-rmse:18.7961	validation_1-rmse:18.8
# [1773]	validation_0-rmse:18.7894	validation_1-rmse:18.7987
# [1774]	validation_0-rmse:18.7893	validation_1-rmse:18.7987
# [1775]	validation_0-rmse:18.7893	validation_1-rmse:18.7987
# [1776]	validation_0-rmse:18.7893	validation_1-rmse:18.7987
# [1777]	validation_0-rmse:18.7892	validation_1-rmse:18.7987
# [1778]	validation_0-rmse:18.7892	validation_1-rmse:18.7987
# [1779]	validation_0-rmse:18.7892	validation_1-rmse:18.7987
# [1780]	validation_0-rmse:18.7891	validation_1-rmse:18.7987
# [1781]	validation_0-rmse:18.7891	validation_1-rmse:18.7987
# [1782]	validation_0-rmse:18.7891	validation_1-rmse:18.7986
# [1783]	validation_0-rmse:18.789	validation_1-rmse:18.7986
# [1784]	validation_0-rmse:18.789	validation_1-rmse:18.7986
# [1785]	validation_0-rmse:18.789	validation_1-rmse:18.7986
# [1786]	validation_0-rmse:18.789	validation_1-rmse:18.7986
# [1787]	validation_0-rmse:18.7889	validation_1-rmse:18.7986
# [1788]	validation_0-rmse:18.7888	validation_1-rmse:18.7985
# [1789]	validation_0-rmse:18.7888	validation_1-rmse:18.7985
# [1790]	validation_0-rmse:18.7887	validation_1-rmse:18.7985
# [1791]	validation_0-rmse:18.7887	validation_1-rmse:18.7985
# [1792]	validation_0-rmse:18.7887	validation_1-rmse:18.7984
# [1793]	validation_0-rmse:18.7887	validation_1-rmse:18.7984
# [1794]	validation_0-rmse:18.7886	validation_1-rmse:18.7984
# [1795]	validation_0-rmse:18.7886	validation_1-rmse:18.7984
# [1796]	validation_0-rmse:18.7885	validation_1-rmse:18.7984
# [1797]	validation_0-rmse:18.7885	validation_1-rmse:18.7984
# [1798]	validation_0-rmse:18.7885	validation_1-rmse:18.7984
# [1799]	validation_0-rmse:18.7885	validation_1-rmse:18.7984
# [1800]	validation_0-rmse:18.7884	validation_1-rmse:18.7984
# [1801]	validation_0-rmse:18.7884	validation_1-rmse:18.7984
# [1802]	validation_0-rmse:18.7883	validation_1-rmse:18.7985
# [1803]	validation_0-rmse:18.7883	validation_1-rmse:18.7985
# [1804]	validation_0-rmse:18.7883	validation_1-rmse:18.7985
# [1805]	validation_0-rmse:18.7882	validation_1-rmse:18.7985
# [1806]	validation_0-rmse:18.7882	validation_1-rmse:18.7985
# Stopping. Best iteration:
# [1796]	validation_0-rmse:18.7885	validation_1-rmse:18.7984
# XGBRegressor(learning_rate=0.05, max_depth=4, n_estimators=2000, n_jobs=-1)

# %% [markdown]
# **The value of n_estimators where the accuracy of the model stops improving significantly is about 1500. This value will be used moving forward.**

# %%
# Save best hyperparameter setting with n_estimators from early stopping
best_model = xgboost.XGBRegressor(learning_rate=0.05, max_depth=4, n_estimators=1500, n_jobs=-1)

# %%
# Run model the same way as the intial test to see improvement of MSE
evaluate_model(best_model)
# Out:
# [22:43:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:49:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:56:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:02:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:09:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#
# Model:
#  XGBRegressor(learning_rate=0.05, max_depth=4, n_estimators=1500, n_jobs=-1)
#     Standard Deviation of Cross Validation MSEs:
#      1.37
#     Mean 5-Fold Cross Validation MSE:
#      355.62
# 355.62

# %% [markdown]
# #### The model has not improved by much after some fine-tuning, but these new hyperparameters will still be utilized for deployment.

# %% [markdown]
# ## Part 4 - DEPLOY

# %% [markdown]
# ### ---- Automate pipeline ----

# %%
# Function that trains model on entire training set and saves model to disk

def load_clean_model_data(raw_train_features, raw_train_targets):
    
    # Load csv files
    df_features = pd.read_csv(raw_train_features)
    df_targets = pd.read_csv(raw_train_targets) 

    # Clean feature and target dataframes per analysis above
    df = pd.merge(df_features, df_targets, on='jobId')
    df = df[df['salary'] > 8.5]
    df_categories = df[['jobType', 'degree', 'major', 'industry']]
    df_categories = pd.get_dummies(df_categories, drop_first=True)
    df_features = pd.concat([df_categories, df[['yearsExperience', 'milesFromMetropolis']]], axis=1)
    df_targets = df[['salary']]
    del df_categories, df
    
    # Implement best model discovered per analysis above
    model = xgboost.XGBRegressor(learning_rate=0.05, max_depth=4, n_estimators=1500)
    model.fit(df_features, df_targets)
    
    # Save model to disk
    model_file = 'model'
    pickle.dump(model, open(model_file, 'wb'))
    
    # Informs user that process is complete
    print("Data prepraration and model creation complete.")

# %%
# Script that prepares data, predicts salaries, and exports results
# This class will be saved in a .py file for private use - See "Salary_Prediction_Module.py"
class salary_prediction_model():
    
    # Read the 'model' file which was saved
    def __init__(self, model_file):
        self.xgb = pickle.load(open(model_file, 'rb'))
    
    # Takes data, prepares data, makes predictions from trained model, and exports results to csv file
    def export_predictions(self, data_file):

        # Load csv file
        df_pred_features = pd.read_csv(data_file)
    
        # Saves jobId column for output file
        df_pred_jobId = pd.DataFrame(df_pred_features['jobId'])
    
        # Prepares data to be fed into the model
        df_pred_categories = df_pred_features[['jobType', 'degree', 'major', 'industry']]
        df_pred_categories = pd.get_dummies(df_pred_categories, drop_first=True)
        df_pred_features = pd.concat([df_pred_categories, df_pred_features[['yearsExperience','milesFromMetropolis']]], axis=1)
        del df_pred_categories
    
        # Loads model from disk, predicts salaries, and exports results to .csv file
        df_pred = pd.DataFrame(self.xgb.predict(df_pred_features))
        df_pred.columns = ['salary']
        df_pred = pd.concat([df_pred_jobId,df_pred], axis=1)
        df_pred.to_csv('predicted_salaries.csv')
        del df_pred_jobId
        
        # Informs user that process is complete
        print("Predictions exported to .csv file.")
    
    # Plot feature importance of model and save figure to .jpg file
    def export_feature_importance(self):
        fig, ax = plt.subplots(figsize=(12, 8))
        xgboost.plot_importance(self.xgb, height=0.6, ax=ax)
        fig.savefig('feature_importance.jpg')
    
        # Informs user that process is complete
        print("Feature importances exported to .jpg file.")

# %% [markdown]
# ### ---- Deploy solution ----

# %%
# Use pipeline to prepare data, fit to model, and save to disk
load_clean_model_data("data/train_features.csv", "data/train_salaries.csv")
# Out:
# [23:15:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Data prepraration and model creation complete.

# %%
# Load and initialize the saved model
model = salary_prediction_model('model')
# Out:
# [23:41:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# Prepare new data and export predictions to .csv file
model.export_predictions("data/test_features.csv")
# Out:
# Predictions exported to .csv file.

# %%
# Export feature importance chart
model.export_feature_importance()
# Out:
# Feature importances exported to .jpg file.
